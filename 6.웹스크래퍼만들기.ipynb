# %% [markdown]
# <a href="https://colab.research.google.com/github/nado6miri/PromptEngineering/blob/main/6.%EC%9B%B9%EC%8A%A4%ED%81%AC%EB%9E%98%ED%8D%BC%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📢 [프롬프트 엔지니어링, LLM(ChatGPT) 기반의 AI 서비스 개발](https://fastcampus.co.kr/data_red_golbin) 강의에서 사용하는 예제입니다.

# %%
# !pip install openai
# !pip install requests
# !pip install bs4

# %%
from openai import OpenAI

client = OpenAI(
    api_key="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"
)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://finance.naver.com/sise/sise_group.naver?type=upjong'

res = requests.get(url)

soup = BeautifulSoup(res.content, 'html.parser')
print("soup = ", soup)

text = soup.find_all(string=True)

except_tags = ['[document]', 'title', 'noscript', 'header', 'html', 'meta', 'head', 'input','script', 'style']

output = ''
for t in text:
    if t.parent.name not in except_tags:
        output += '{} '.format(t)

print(output)
# Out:
# soup =
# <!--  global include -->
# <html lang="ko">
# <head>
# <title>업종별 시세 : 네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title">
# <meta content="http://finance.naver.com/sise/sise_group.naver" property="og:url">
# <meta content="업종별 시세 : 네이버페이 증권" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup

except_tags = ['[document]', 'title', 'noscript', 'header', 'html', 'meta', 'head', 'input','script', 'style']

def scrap_web(url: str):
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    text = soup.find_all(string=True)

    text_all = ''
    for t in text:
        if t.parent.name not in except_tags:
            text_all += '{} '.format(t)

    return text_all

# %%
def extract_stock_status(content, temperature=0, max_tokens=2048):
#     user_message = f"""다음은 주가 정보 페이지를 복사해 온 정보야. 다음 정보에서 주가 업종과 시세, 등락 정보를 추출해서 표로 만들어줘.
# {content}
# """
    user_message = f"""다음은 주가 정보 페이지를 복사해 온 정보야. 다음 정보에서 주가 업종과 시세, 등락 정보를 추출해서 JSON 포맷으로 만들어줘. 최상위 10개만 출력해줘.
{content}
"""

    completion = client.chat.completions.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {
                "role": "user",
                "content": user_message
            }
        ],
        temperature=temperature,
        max_tokens=max_tokens,
    )

    return completion.choices[0].message.content

# %%
url = 'https://finance.naver.com/sise/sise_group.naver?type=upjong'

web_text = scrap_web(url)

result = extract_stock_status(web_text)

print(result)
# Out:
# {
#   "주가 업종": [
#     {
#       "업종명": "자동차",
#       "전일대비": "+10.16%",
#       "전일대비 등락현황": {
#         "상승": 15,
#         "보합": 12,
#         "하락": 1,
#         "상한가": 2,
#         "하한가": 100%
#       }
#     },
#     {
#       "업종명": "양방향미디어와서비스",
#       "전일대비": "+8.04%",
#       "전일대비 등락현황": {
#         "상승": 17,
#         "보합": 11,
#         "하락": 1,
#         "상한가": 5,
#         "하한가": 79%
#       }
#     },
#     {
#       "업종명": "은행",
#       "전일대비": "+5.92%",
#       "전일대비 등락현황": {
#         "상승": 11,
#         "보합": 8,
#         "하락": 0,
#         "상한가": 3,
#         "하한가": 58%
#       }
#     },
#     {
#       "업종명": "가정용기기와용품",
#       "전일대비": "+5.88%",
#       "전일대비 등락현황": {
#         "상승": 21,
#         "보합": 14,
#         "하락": 4,
#         "상한가": 3,
#         "하한가": 57%
#       }
#     },
#     {
#       "업종명": "기타금융",
#       "전일대비": "+5.52%",
#       "전일대비 등락현황": {
#         "상승": 6,
#         "보합": 4,
#         "하락": 1,
#         "상한가": 1,
# ...
